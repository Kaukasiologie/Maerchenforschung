# %% [markdown]
# ## annotation(en)
# #### Hier lassen sich Annotationen der Texte nach einem bestimmten oder nach beliebigen Typen abrufen.

# %%
from zusammenfassung import (
    frage_typ_ab,
    zusammenfassung_notebook,
    zeige_zusammenfassung
)

Repertoire = 'test.xml'

Gesuchter_Typ = frage_typ_ab()

text, mit_treffern, ohne_treffern = zusammenfassung_notebook(
    Repertoire,
    Gesuchter_Typ
)

zeige_zusammenfassung(mit_treffern, ohne_treffern)
print(text)
